# %%
# looping statements
i = 1
while i >= 5:
    print(python)
    i = i+1

# %%
n = int(input())
t = n
s = 0
while t > 0:
    d = t % 10
    s = s + d**3
    t = t // 10
if s == n:
    print("Armstrong")
else:
    print("Not Armstrong")
# Out:
# Not Armstrong

# %%
n = 17
print(n)
# Out:
# 17

# %%
n = input()
i = 0
while i < len(n):
    if 'A' <= n[i] <=  'Z':
        str += chr(ord(n[i]) + 32)
    else:
        str += n[i]
    i += 1
print(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       5         str += chr(ord(n[i]) + 32)
#       6     else:
# ----> 7         str += n[i]
#       8     i += 1
#       9 print(str)
#
# TypeError: unsupported operand type(s) for +=: 'type' and 'str'

# %%
n = eval(input())
small = n[0]
i = 1
while i < len(n):
    if n[i] < small:
        small = n[i]
    i += 1
print(n)
print(small)
# Out:
# [10, 20, 30, 40, 50]
# 10

# %%
#write a program to print 2nd largest number in a given list of number using homogeneousn
n = eval(input())

second_largest = n[0]
third_largest = n[0]

i = 1
while i < len(n):
    if n[i] > second_largest:
        second_largest = third_largest
        _largest = n[i]
    elif n[i] > second_largest and n[i] != largest:
        second_largest = n[i]
    i += 1

print(n)
print(second_largest)
# Out:
# [10, 20, 30, 40, 50]
# 40

# %%
# Out:
# 40
